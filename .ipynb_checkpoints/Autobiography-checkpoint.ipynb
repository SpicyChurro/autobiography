# %% [markdown]
# ![profile2.png](attachment:profile2.png)
#
# ## Ricardo Quintero Slazar
#
# I started pursuing a Bachelor's in Digital Animation, which got me hooked on tech and programming. After that, I jumped into Project Management for my postgrad, learning the ropes of steering projects of multiple purposes. After finishing project management and before diving headfirst into Data Science for my Master's, I've bounced around roles - from a web developer at an investment center, to keeping things running smoothly as a web admin at a lightbulbs manufacturing company.
#
# Currently, I'm having a really good time as a Django Developer at a software solutions company. My journey has been a whirlwind of experiences, each adding new skills and angles. The tech world keeps evolving, and I'm ready for more challenges and exciting stuff ahead.
